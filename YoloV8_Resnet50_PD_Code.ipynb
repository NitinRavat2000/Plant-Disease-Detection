# %%
! git clone https://github.com/ultralytics/ultralytics.git
# Out:
# Cloning into 'ultralytics'...
# remote: Enumerating objects: 20279, done.
# remote: Counting objects: 100% (611/611), done.
# remote: Compressing objects: 100% (382/382), done.
# remote: Total 20279 (delta 303), reused 432 (delta 226), pack-reused 19668
# Receiving objects: 100% (20279/20279), 11.89 MiB | 8.96 MiB/s, done.
# Resolving deltas: 100% (14088/14088), done.

# %%
pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 699.2/699.2 kB 6.7 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

# %%
model = YOLO("/content/runs/detect/train/weights/last.pt")

# %%
from re import T
results = model.train(data='/content/drive/MyDrive/PrinceResnetYoloCode/data.yaml', epochs=300, imgsz=640, batch=4, resume=True)
# Out:
# Ultralytics YOLOv8.1.0 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
import shutil

# Specify the paths
source_path = '/content/runs/detect/predict'  # Change this to the actual path of your "runs" folder
destination_path = '/content/drive/My Drive/'

# Move the folder
shutil.move(source_path, destination_path)
# Out:
# '/content/drive/My Drive/predict'

# %%
import shutil

folder_path = "/content/runs/detect/predict"
shutil.make_archive("/content/predict", 'zip', folder_path)
# Out:
# '/content/predict.zip'

# %%
from google.colab import files

files.download("/content/predict.zip")

# %%
! yolo detect predict model="/content/drive/MyDrive/detect/train/weights/best.pt" source="/content/drive/MyDrive/PrinceResnetYoloCode/new_plant_data/test"
# Out:
# Ultralytics YOLOv8.1.0 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8l summary (fused): 307 layers, 49194716 parameters, 0 gradients, 150.8 GFLOPs
#
# image 1/80 /content/drive/MyDrive/PrinceResnetYoloCode/new_plant_data/test/10_A.jpg: 448x640 1 Army_worm, 80.7ms
# image 2/80 /content/drive/MyDrive/PrinceResnetYoloCode/new_plant_data/test/10_B.jpg: 608x640 1 Bacterial_Blight, 77.7ms
# image 3/80 /content/drive/MyDrive/PrinceResnetYoloCode/new_plant_data/test/10_H.jpg: 640x640 1 Healthy, 67.5ms
# image 4/80 /content/drive/MyDrive/PrinceResnetYoloCode/new_plant_data/test/10_P.jpg: 576x640 1 Powdery_Mildew, 80.4ms
# image 5/80 /content/drive/MyDrive/PrinceResnetYoloCode/new_plant_data/test/11_A.jpg: 448x640 1 Army_worm, 52.5ms
# image 6/80 /content/drive/MyDrive/PrinceResnetYoloCode/new_plant_data/test/11_B.jpg: 640x576 1 Bacterial_Blight, 77.4ms
# image 7/80 /content/drive/MyDrive/PrinceResnetYoloCode/new_plant_data/test/11_H.jpg: 512x640 1 Healthy, 85.3ms
# ...
